# %%
# 1 selection and slicing
import pandas as pd
df=pd.read_csv("C:/Users/anant/Downloads/task/nba (1).csv")
print(df.head(10))
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7   Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# 8   Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 9   Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         NaN
# 3      Georgia State   1148640.0
# ...

# %%
df=pd.read_csv("C:/Users/anant/Downloads/task/nba (1).csv")
columns=df.loc[:19,['Name','Team']]
print(columns)
# Out:
#                        Name            Team
# 0             Avery Bradley  Boston Celtics
# 1               Jae Crowder  Boston Celtics
# 2              John Holland  Boston Celtics
# 3               R.J. Hunter  Boston Celtics
# 4             Jonas Jerebko  Boston Celtics
# 5              Amir Johnson  Boston Celtics
# 6             Jordan Mickey  Boston Celtics
# 7              Kelly Olynyk  Boston Celtics
# 8              Terry Rozier  Boston Celtics
# 9              Marcus Smart  Boston Celtics
# 10          Jared Sullinger  Boston Celtics
# 11            Isaiah Thomas  Boston Celtics
# 12              Evan Turner  Boston Celtics
# 13              James Young  Boston Celtics
# 14             Tyler Zeller  Boston Celtics
# 15         Bojan Bogdanovic   Brooklyn Nets
# 16             Markel Brown   Brooklyn Nets
# 17          Wayne Ellington   Brooklyn Nets
# 18  Rondae Hollis-Jefferson   Brooklyn Nets
# 19             Jarrett Jack   Brooklyn Nets

# %%
import pandas as pd
df=pd.read_csv("C:/Users/anant/Downloads/task/nba (1).csv")
df['Team']=='Boston Celtics'
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 453    False
# 454    False
# 455    False
# 456    False
# 457    False
# Name: Team, Length: 458, dtype: bool

# %%
df=pd.read_csv("C:/Users/anant/Downloads/task/nba (1).csv")
player=df.loc[df['Team']=='Boston Celtics']
print(player)
# Out:
#                Name            Team  Number Position   Age Height  Weight  \
# 0     Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1       Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2      John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3       R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4     Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5      Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6     Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7      Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# 8      Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 9      Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
# 10  Jared Sullinger  Boston Celtics     7.0        C  24.0    6-9   260.0
# 11    Isaiah Thomas  Boston Celtics     4.0       PG  27.0    5-9   185.0
# ...

# %%
df.iloc[10:20]
# Out:
#                        Name            Team  Number Position   Age Height  \
# 10          Jared Sullinger  Boston Celtics     7.0        C  24.0    6-9
# 11            Isaiah Thomas  Boston Celtics     4.0       PG  27.0    5-9
# 12              Evan Turner  Boston Celtics    11.0       SG  27.0    6-7
# 13              James Young  Boston Celtics    13.0       SG  20.0    6-6
# 14             Tyler Zeller  Boston Celtics    44.0        C  26.0    7-0
# 15         Bojan Bogdanovic   Brooklyn Nets    44.0       SG  27.0    6-8
# 16             Markel Brown   Brooklyn Nets    22.0       SG  24.0    6-3
# 17          Wayne Ellington   Brooklyn Nets    21.0       SG  28.0    6-4
# 18  Rondae Hollis-Jefferson   Brooklyn Nets    24.0       SG  21.0    6-7
# 19             Jarrett Jack   Brooklyn Nets     2.0       PG  32.0    6-3
#
#     Weight         College     Salary
# 10   260.0      Ohio State  2569260.0
# 11   185.0      Washington  6912869.0
# ...

# %%
# 2 adding deleting rows and columns
import pandas as pd 
df=pd.read_csv("C:/Users/anant/Downloads/task/nba (1).csv")
df['experience'] = 2024 - df['Age']
print(df)
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary  experience
# ...

# %%
droppeddf=df.drop(columns=['College'])
droppeddf
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#         Salary  experience
# 0    7730337.0      1999.0
# 1    6796117.0      1999.0
# ...

# %%
df=pd.read_csv("C:/Users/anant/Downloads/task/nba (1).csv")
new_player=pd.DataFrame({'Name': ['player'], 'Team' : ['boston'], 'number' : [3], 'college':['ihrd']})
df=pd.concat([df,new_player], ignore_index=True)
print(df)
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
# 458         player          boston     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary  number college
# ...

# %%
drop_row=df.drop(0)
drop_row
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5     Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College      Salary
# 1            Marquette   6796117.0
# ...

# %%
# 3 boolean indexing and masking
import pandas as pd
df=pd.read_csv("C:/Users/anant/Downloads/task/nba (1).csv")
high_salary=df[df['Salary']> 5000000]
print(high_salary.to_string())
# Out:
#                        Name                    Team  Number Position   Age Height  Weight             College      Salary
# 0             Avery Bradley          Boston Celtics     0.0       PG  25.0    6-2   180.0               Texas   7730337.0
# 1               Jae Crowder          Boston Celtics    99.0       SF  25.0    6-6   235.0           Marquette   6796117.0
# 5              Amir Johnson          Boston Celtics    90.0       PF  29.0    6-9   240.0                 NaN  12000000.0
# 11            Isaiah Thomas          Boston Celtics     4.0       PG  27.0    5-9   185.0          Washington   6912869.0
# 19             Jarrett Jack           Brooklyn Nets     2.0       PG  32.0    6-3   200.0        Georgia Tech   6300000.0
# 23              Brook Lopez           Brooklyn Nets    11.0        C  28.0    7-0   275.0            Stanford  19689000.0
# 29           Thaddeus Young           Brooklyn Nets    30.0       PF  27.0    6-8   221.0        Georgia Tech  11235955.0
# ...

# %%
# 4 creating series and dataframe
import pandas as pd
df=pd.read_csv("C:/Users/anant/Downloads/task/nba (1).csv")
name_series=df["Name"]
print(name_series)
# Out:
# 0      Avery Bradley
# 1        Jae Crowder
# 2       John Holland
# 3        R.J. Hunter
# 4      Jonas Jerebko
#            ...
# 453     Shelvin Mack
# 454        Raul Neto
# 455     Tibor Pleiss
# 456      Jeff Withey
# 457              NaN
# Name: Name, Length: 458, dtype: object

# %%
new_df=df[df['Position'].isin(['SG','PG'])]
print(new_df)
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 8     Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 9     Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 444     Alec Burks       Utah Jazz    10.0       SG  24.0    6-6   214.0
# 445     Dante Exum       Utah Jazz    11.0       PG  20.0    6-6   190.0
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
# 5 locating specific columns and rows
df=pd.read_csv("C:/Users/anant/Downloads/task/nba (1).csv")
jj=df[df['Name']=='Jonas Jerebko']
print(jj)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#   College     Salary
# 4     NaN  5000000.0

# %%
loc=df.loc[df['Age']>25 ,['Name','Salary']]
print(loc)
# Out:
#               Name      Salary
# 2     John Holland         NaN
# 4    Jonas Jerebko   5000000.0
# 5     Amir Johnson  12000000.0
# 11   Isaiah Thomas   6912869.0
# 12     Evan Turner   3425510.0
# ..             ...         ...
# 450     Joe Ingles   2050000.0
# 451  Chris Johnson    981348.0
# 453   Shelvin Mack   2433333.0
# 455   Tibor Pleiss   2900000.0
# 456    Jeff Withey    947276.0
#
# [258 rows x 2 columns]

# %%
df2=df.iloc[:51, 5:7:1]
display(df2)
# Out:
#    Height  Weight
# 0     6-2   180.0
# 1     6-6   235.0
# 2     6-5   205.0
# 3     6-5   185.0
# 4    6-10   231.0
# 5     6-9   240.0
# 6     6-8   235.0
# 7     7-0   238.0
# 8     6-2   190.0
# 9     6-4   220.0
# 10    6-9   260.0
# 11    5-9   185.0
# 12    6-7   220.0
# 13    6-6   215.0
# 14    7-0   253.0
# 15    6-8   216.0
# 16    6-3   190.0
# 17    6-4   200.0
# 18    6-7   220.0
# 19    6-3   200.0
# 20    6-7   208.0
# 21    6-4   219.0
# 22   5-11   175.0
# 23    7-0   275.0
# 24   6-11   200.0
# 25   6-10   220.0
# 26   6-10   237.0
# 27   6-10   248.0
# 28    6-3   205.0
# 29    6-8   221.0
# 30    6-5   210.0
# 31    6-9   220.0
# 32    6-7   205.0
# 33    6-8   240.0
# 34    6-3   200.0
# 35    6-8   210.0
# 36    6-2   200.0
# 37    6-4   195.0
# 38    7-0   255.0
# 39   6-10   250.0
# 40    7-3   240.0
# 41   6-10   278.0
# 42    6-8   235.0
# 43    6-7   195.0
# 44    6-8   240.0
# 45    6-6   205.0
# 46    6-9   254.0
# 47    6-0   201.0
# 48    6-9   215.0
# ...

# %%
# 6 data cleaning
import pandas as pd

df=pd.read_csv("C:/Users/anant/Downloads/task/nba (1).csv")
empty_salary=df[df['Salary'].isna()]
display(empty_salary)
# Out:
#                Name                    Team  Number Position   Age Height  \
# 2      John Holland          Boston Celtics    30.0       SG  27.0    6-5
# 46      Elton Brand      Philadelphia 76ers    42.0       PF  37.0    6-9
# 171   Dahntay Jones     Cleveland Cavaliers    30.0       SG  35.0    6-6
# 264   Jordan Farmar       Memphis Grizzlies     4.0       PG  29.0    6-2
# 269    Ray McCallum       Memphis Grizzlies     5.0       PG  24.0    6-3
# 270  Xavier Munford       Memphis Grizzlies    14.0       PG  24.0    6-3
# 273  Alex Stepheson       Memphis Grizzlies    35.0       PF  28.0   6-10
# 350   Briante Weber              Miami Heat    12.0       PG  23.0    6-2
# 353   Dorell Wright              Miami Heat    11.0       SF  30.0    6-9
# 397    Axel Toupane          Denver Nuggets     6.0       SG  23.0    6-7
# 409      Greg Smith  Minnesota Timberwolves     4.0       PF  25.0   6-10
# 457             NaN                     NaN     NaN      NaN   NaN    NaN
#
# ...

# %%
x=df['Salary'].mean()
df['Salary'].fillna(x, inplace=True)
display(df)
# Out:
# C:\Users\anant\AppData\Local\Temp\ipykernel_43964\613789074.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Salary'].fillna(x, inplace=True)
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# ...

# %%
df.dropna(inplace=True)
display(df.to_string)
# Out:
# <bound method DataFrame.to_string of               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College        Salary
# ...

# %%
df['Height']=df['Height'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df['Height']=df['Height'].astype(float)
#
# File c:\Users\anant\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File c:\Users\anant\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...
