# %%
# importing pandas module
import pandas as pd

# Define a dictionary containing employee data
data1 = {'Name':['Jai', 'Anuj', 'Jai', 'Princi',
                 'Gaurav', 'Anuj', 'Princi', 'Abhi'],
        'Age':[27, 24, 22, 32,
               33, 36, 27, 32],
        'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj',
                   'Jaunpur', 'Kanpur', 'Allahabad', 'Aligarh'],
        'Qualification':['Msc', 'MA', 'MCA', 'Phd',
                         'B.Tech', 'B.com', 'Msc', 'MA']}
df=pd.DataFrame(data1)
display(df)
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1    Anuj   24     Kanpur            MA
# 2     Jai   22  Allahabad           MCA
# 3  Princi   32    Kannuaj           Phd
# 4  Gaurav   33    Jaunpur        B.Tech
# 5    Anuj   36     Kanpur         B.com
# 6  Princi   27  Allahabad           Msc
# 7    Abhi   32    Aligarh            MA

# %%
group=df.groupby('Name')
group.get_group('Anuj')
# Out:
#    Name  Age Address Qualification
# 1  Anuj   24  Kanpur            MA
# 5  Anuj   36  Kanpur         B.com

# %%
group=df.groupby(['Name','Qualification'])
group.get_group(('Jai','Msc'))
# Out:
#   Name  Age Address Qualification
# 0  Jai   27  Nagpur           Msc

# %%
# importing pandas module
import pandas as pd

# importing numpy as np
import numpy as np

# Define a dictionary containing employee data
data1 = {'Name':['Jai', 'Anuj', 'Jai', 'Princi',
                 'Gaurav', 'Anuj', 'Princi', 'Abhi'],
        'Age':[27, 24, 22, 32,
               33, 36, 27, 32],
        'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj',
                   'Jaunpur', 'Kanpur', 'Allahabad', 'Aligarh'],
        'Qualification':['Msc', 'MA', 'MCA', 'Phd','B.Tech', 'B.com', 'Msc', 'MA'],
        'Score': [23, 34, 35, 45, 47, 50, 52, 53]}


# Convert the dictionary into DataFrame
df = pd.DataFrame(data1)
display(df)
# Out:
#      Name  Age    Address Qualification  Score
# 0     Jai   27     Nagpur           Msc     23
# 1    Anuj   24     Kanpur            MA     34
# 2     Jai   22  Allahabad           MCA     35
# 3  Princi   32    Kannuaj           Phd     45
# 4  Gaurav   33    Jaunpur        B.Tech     47
# 5    Anuj   36     Kanpur         B.com     50
# 6  Princi   27  Allahabad           Msc     52
# 7    Abhi   32    Aligarh            MA     53

# %%
import numpy as np
name_group=df.groupby('Name')
name_group.aggregate(np.sum)
# Out:
# C:\Users\anant\AppData\Local\Temp\ipykernel_112952\1671818477.py:3: FutureWarning: The provided callable <function sum at 0x0000019077102980> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   name_group.aggregate(np.sum)
#         Age           Address Qualification  Score
# Name
# Abhi     32           Aligarh            MA     53
# Anuj     60      KanpurKanpur       MAB.com     84
# Gaurav   33           Jaunpur        B.Tech     47
# Jai      49   NagpurAllahabad        MscMCA     58
# Princi   59  KannuajAllahabad        PhdMsc     97

# %%
group2=df.groupby(['Name','Qualification'])
group2.aggregate(np.sum)
# Out:
# C:\Users\anant\AppData\Local\Temp\ipykernel_112952\2918987001.py:2: FutureWarning: The provided callable <function sum at 0x0000019077102980> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   group2.aggregate(np.sum)
#                       Age    Address  Score
# Name   Qualification
# Abhi   MA              32    Aligarh     53
# Anuj   B.com           36     Kanpur     50
#        MA              24     Kanpur     34
# Gaurav B.Tech          33    Jaunpur     47
# Jai    MCA             22  Allahabad     35
#        Msc             27     Nagpur     23
# Princi Msc             27  Allahabad     52
#        Phd             32    Kannuaj     45

# %%
name_group=df.groupby('Name')
name_group['Age'].agg([np.sum , np.mean, np.std])
# Out:
# C:\Users\anant\AppData\Local\Temp\ipykernel_112952\2406590312.py:2: FutureWarning: The provided callable <function sum at 0x0000019077102980> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   name_group['Age'].agg([np.sum , np.mean, np.std])
# C:\Users\anant\AppData\Local\Temp\ipykernel_112952\2406590312.py:2: FutureWarning: The provided callable <function mean at 0x0000019077103D80> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   name_group['Age'].agg([np.sum , np.mean, np.std])
# ...

# %%
name_group=df.groupby('Name')
name_group.agg({'Age':'sum', 'Score':"mean"})
# Out:
#         Age  Score
# Name
# Abhi     32   53.0
# Anuj     60   42.0
# Gaurav   33   47.0
# Jai      49   29.0
# Princi   59   48.5

# %%
name_group=df.groupby('Name')
sc=lambda x: (x - x.mean()) / x.std()*10
name_group[['Age','Score']].transform(sc)
# Out:
#         Age     Score
# 0  7.071068 -7.071068
# 1 -7.071068 -7.071068
# 2 -7.071068  7.071068
# 3  7.071068 -7.071068
# 4       NaN       NaN
# 5  7.071068  7.071068
# 6 -7.071068  7.071068
# 7       NaN       NaN

# %%
data = {'Team': ['A', 'A', 'B', 'B', 'C', 'C'],
        'Score': [10, 20, 15, 30, 50, 60]}
df = pd.DataFrame(data)
display(df)
# Out:
#   Team  Score
# 0    A     10
# 1    A     20
# 2    B     15
# 3    B     30
# 4    C     50
# 5    C     60

# %%
teamgrp=df.groupby('Team')
df['mean']=teamgrp['Score'].transform('mean')
display(df)
# Out:
#   Team  Score  mean
# 0    A     10  15.0
# 1    A     20  15.0
# 2    B     15  22.5
# 3    B     30  22.5
# 4    C     50  55.0
# 5    C     60  55.0

# %%
data1 = {'Name':['Jai', 'Anuj', 'Jai', 'Princi',
                 'Gaurav', 'Anuj', 'Princi', 'Abhi'],
        'Age':[27, 24, 22, 32,
               33, 36, 27, 32],
        'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj',
                   'Jaunpur', 'Kanpur', 'Allahabad', 'Aligarh'],
        'Qualification':['Msc', 'MA', 'MCA', 'Phd','B.Tech', 'B.com', 'Msc', 'MA'],
        'Score': [23, 34, 35, 45, 47, 50, 52, 53]}


# Convert the dictionary into DataFrame
df = pd.DataFrame(data1)
display(df)
# Out:
#      Name  Age    Address Qualification  Score
# 0     Jai   27     Nagpur           Msc     23
# 1    Anuj   24     Kanpur            MA     34
# 2     Jai   22  Allahabad           MCA     35
# 3  Princi   32    Kannuaj           Phd     45
# 4  Gaurav   33    Jaunpur        B.Tech     47
# 5    Anuj   36     Kanpur         B.com     50
# 6  Princi   27  Allahabad           Msc     52
# 7    Abhi   32    Aligarh            MA     53

# %%
grp=df.groupby('Name')
grp.filter(lambda x : len(x)>=2)
# Out:
#      Name  Age    Address Qualification  Score
# 0     Jai   27     Nagpur           Msc     23
# 1    Anuj   24     Kanpur            MA     34
# 2     Jai   22  Allahabad           MCA     35
# 3  Princi   32    Kannuaj           Phd     45
# 5    Anuj   36     Kanpur         B.com     50
# 6  Princi   27  Allahabad           Msc     52

# %%
data = {'Team': ['A', 'A', 'B', 'B', 'C', 'C'],
        'Score': [10, 20, 15, 30, 50, 60]}
df = pd.DataFrame(data)
teamgrp=df.groupby('Team')
teamgrp.filter(lambda x:x['Score'].max()>=40)
# Out:
#   Team  Score
# 4    C     50
# 5    C     60

# %%
# importing pandas as pd
import pandas as pd

# Create dictionary with data
dict = {
    "ID":[1, 2, 3],
    "Movies":["The Godfather", "Fight Club", "Casablanca"],
    "Week_1_Viewers":[30, 30, 40],
    "Week_2_Viewers":[60, 40, 80],
    "Week_3_Viewers":[40, 20, 20] };

# Convert dictionary to dataframe
df = pd.DataFrame(dict);
print(df)
# Out:
#    ID         Movies  Week_1_Viewers  Week_2_Viewers  Week_3_Viewers
# 0   1  The Godfather              30              60              40
# 1   2     Fight Club              30              40              20
# 2   3     Casablanca              40              80              20

# %%
groupby_dict={'Week_1_Viewers':'Total_viewers',
              'Week_2_Viewers':'Total_viewers',
             'Week_3_Viewers':'Total_viewers',
              'Movies':'Movies' }
df=df.set_index('ID')
df=df.groupby(groupby_dict,axis=1).sum()
display(df)
# Out:
# C:\Users\anant\AppData\Local\Temp\ipykernel_119936\988690578.py:6: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df=df.groupby(groupby_dict,axis=1).sum()
#            Movies  Total_viewers
# ID
# 1   The Godfather            130
# 2      Fight Club             90
# 3      Casablanca            140

# %%
# importing pandas module
import pandas as pd

# Define a dictionary containing employee data
data1 = {'Name': ['Jai', 'Princi', 'Gaurav', 'Anuj'],
         'Age': [27, 24, 22, 32],
         'Address': ['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
         'Qualification': ['Msc', 'MA', 'MCA', 'Phd']}
# Define a dictionary containing employee data
data2 = {'Name': ['Abhi', 'Ayushi', 'Dhiraj', 'Hitesh'],
         'Age': [17, 14, 12, 52],
         'Address': ['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
         'Qualification': ['Btech', 'B.A', 'Bcom', 'B.hons']}
# Convert the dictionary into DataFrame
df = pd.DataFrame(data1, index=[0, 1, 2, 3])

# Convert the dictionary into DataFrame
df1 = pd.DataFrame(data2, index=[4, 5, 6, 7])

print(df, "\n\n", df1)
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3    Anuj   32    Kannuaj           Phd
#
#       Name  Age    Address Qualification
# 4    Abhi   17     Nagpur         Btech
# 5  Ayushi   14     Kanpur           B.A
# 6  Dhiraj   12  Allahabad          Bcom
# 7  Hitesh   52    Kannuaj        B.hons

# %%
frames=[df,df1]

res1=pd.concat(frames)
res1
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3    Anuj   32    Kannuaj           Phd
# 4    Abhi   17     Nagpur         Btech
# 5  Ayushi   14     Kanpur           B.A
# 6  Dhiraj   12  Allahabad          Bcom
# 7  Hitesh   52    Kannuaj        B.hons

# %%
# importing pandas module
import pandas as pd

# Define a dictionary containing employee data
data1 = {'Name': ['Jai', 'Princi', 'Gaurav', 'Anuj'],
         'Age': [27, 24, 22, 32],
         'Address': ['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
         'Qualification': ['Msc', 'MA', 'MCA', 'Phd'],
         'Mobile No': [97, 91, 58, 76]}
# Define a dictionary containing employee data
data2 = {'Name': ['Gaurav', 'Anuj', 'Dhiraj', 'Hitesh'],
         'Age': [22, 32, 12, 52],
         'Address': ['Allahabad', 'Kannuaj', 'Allahabad', 'Kannuaj'],
         'Qualification': ['MCA', 'Phd', 'Bcom', 'B.hons'],
         'Salary': [1000, 2000, 3000, 4000]}
# Convert the dictionary into DataFrame
df = pd.DataFrame(data1, index=[0, 1, 2, 3])

# Convert the dictionary into DataFrame
df1 = pd.DataFrame(data2, index=[2, 3, 6, 7])

print(df, "\n\n", df1)
# Out:
#      Name  Age    Address Qualification  Mobile No
# 0     Jai   27     Nagpur           Msc         97
# 1  Princi   24     Kanpur            MA         91
# 2  Gaurav   22  Allahabad           MCA         58
# 3    Anuj   32    Kannuaj           Phd         76
#
#       Name  Age    Address Qualification  Salary
# 2  Gaurav   22  Allahabad           MCA    1000
# 3    Anuj   32    Kannuaj           Phd    2000
# 6  Dhiraj   12  Allahabad          Bcom    3000
# 7  Hitesh   52    Kannuaj        B.hons    4000

# %%
res12=pd.concat([df,df1], axis=1 , join='inner')
res12
# Out:
#      Name  Age    Address Qualification  Mobile No    Name  Age    Address  \
# 2  Gaurav   22  Allahabad           MCA         58  Gaurav   22  Allahabad
# 3    Anuj   32    Kannuaj           Phd         76    Anuj   32    Kannuaj
#
#   Qualification  Salary
# 2           MCA    1000
# 3           Phd    2000

# %%
res12=pd.concat([df,df1], axis=1).reset_index(drop=True)
res12
# Out:
#      Name   Age    Address Qualification  Mobile No    Name   Age    Address  \
# 0     Jai  27.0     Nagpur           Msc       97.0     NaN   NaN        NaN
# 1  Princi  24.0     Kanpur            MA       91.0     NaN   NaN        NaN
# 2  Gaurav  22.0  Allahabad           MCA       58.0  Gaurav  22.0  Allahabad
# 3    Anuj  32.0    Kannuaj           Phd       76.0    Anuj  32.0    Kannuaj
# 4     NaN   NaN        NaN           NaN        NaN  Dhiraj  12.0  Allahabad
# 5     NaN   NaN        NaN           NaN        NaN  Hitesh  52.0    Kannuaj
#
#   Qualification  Salary
# 0           NaN     NaN
# 1           NaN     NaN
# 2           MCA  1000.0
# 3           Phd  2000.0
# 4          Bcom  3000.0
# 5        B.hons  4000.0

# %%
res12=pd.concat([df,df1],keys=['x','y'])
res12
# Out:
#        Name  Age    Address Qualification  Mobile No  Salary
# x 0     Jai   27     Nagpur           Msc       97.0     NaN
#   1  Princi   24     Kanpur            MA       91.0     NaN
#   2  Gaurav   22  Allahabad           MCA       58.0     NaN
#   3    Anuj   32    Kannuaj           Phd       76.0     NaN
# y 2  Gaurav   22  Allahabad           MCA        NaN  1000.0
#   3    Anuj   32    Kannuaj           Phd        NaN  2000.0
#   6  Dhiraj   12  Allahabad          Bcom        NaN  3000.0
#   7  Hitesh   52    Kannuaj        B.hons        NaN  4000.0

# %%
# importing pandas module
import pandas as pd

# Define a dictionary containing employee data
data1 = {'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'],
        'Age':[27, 24, 22, 32],
        'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
        'Qualification':['Msc', 'MA', 'MCA', 'Phd']}
# Convert the dictionary into DataFrame
df = pd.DataFrame(data1,index=[0, 1, 2, 3])

# creating a series
s1 = pd.Series([1000, 2000, 3000, 4000], name='Salary')

print(df, "\n\n", s1)
# importing pandas module
import pandas as pd

# Define a dictionary containing employee data
data1 = {'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'],
        'Age':[27, 24, 22, 32],
        'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
        'Qualification':['Msc', 'MA', 'MCA', 'Phd']}
# Convert the dictionary into DataFrame
df = pd.DataFrame(data1,index=[0, 1, 2, 3])

# creating a series
s1 = pd.Series([1000, 2000, 3000, 4000], name='Salary')

print(df, "\n\n", s1)
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3    Anuj   32    Kannuaj           Phd
#
#  0    1000
# 1    2000
# 2    3000
# 3    4000
# Name: Salary, dtype: int64
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3    Anuj   32    Kannuaj           Phd
#
#  0    1000
# 1    2000
# 2    3000
# 3    4000
# Name: Salary, dtype: int64

# %%
res12=pd.concat([df,s1], axis=1)
res12
# Out:
#      Name  Age    Address Qualification  Salary
# 0     Jai   27     Nagpur           Msc    1000
# 1  Princi   24     Kanpur            MA    2000
# 2  Gaurav   22  Allahabad           MCA    3000
# 3    Anuj   32    Kannuaj           Phd    4000
